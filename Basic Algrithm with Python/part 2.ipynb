# %% [markdown]
# # Task:
# Suppose you work for an electricity generation and retailing company which wants to setup microgrids within a rural region. The company has done its research and knows all the geo-coded customer locations (nodes) in the region. For the purpose of this assignment, we will simply consider the customer location as points pi = (xi, yi) in two-dimensional space R2 with no further information attached to them.

# %% [markdown]
# ## Question 1:
# Using the ADT class for points in 2-dimensional Euclidean space from before, implement a function to generate a test set of n random nodes/points, where n is a user-definable parameter.

# %%
# define the Point ADT class to constuct point wchich will be used later.
from math import *
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y
        
    def __str__(self):
        return "(" + str(self.x) + ", " + str(self.y) + ")"
    
    def setPoint(self, newx, newy):
        self.x = newx
        self.y = newy
        
    def getPoint(self):
        return self.x, self.y
    
    def distanceFromOrigin(self):
        return sqrt(pow(self.x, 2) + pow(self.y, 2))
    
    def distanceToOther(self, other):
        dx = abs(self.x - other.x)
        dy = abs(self.y - other.y)
        return round(sqrt(pow(dx, 2) + pow(dy, 2)), 2)
    
    def translate(self, dx, dy):
        self.x += dx
        self.y += dy

# %%
# define the point sets function
# create multiple points in random
# the point structure follows the Point ADT class
import random
def pointSet(n):   # make n points into the pointset
    ps = list()
    for i in range(n):   # create n points
        x = random.randint(0, 100)
        y = random.randint(0, 100)
        
        notSame = True 
        for j in ps:     # check if the created point is already exist.
                         # if yes, re-create a new point.
            if x == j.x and y == j.y:
                i -= 1
                notSame = False
                break
        if notSame == True:
            ps.append(Point(x, y))
    return ps

# %% [markdown]
# ## Question 2:
# Implement an ADT class for Partition (union-find). It must support the operations for
# generating a new partition (i.e. a set of sets), for generating a new set within the partition,
# for merging two sets (union) and for finding a set to which an element belongs (find). You
# should use the tree-based implementation. If you need a refresher regarding the Partition
# ADT, consult the lecture notes for spanning trees. Wikipedia also has a good and compact
# explanation here. (*Note: In the pracs, we implemented the union-find procedure. You now
# have to implement it as an ADT class)

# %%
# Create a non-direction graph structure
class Graph:
    def __init__(self, ps):
        self.vertix = ps
        self.edge = list()
        
        # generate edges between every two points
        for i in range(len(self.vertix)-1):
            for j in range(i+1, len(self.vertix)):
                self.edge.append((ps[i].distanceToOther(ps[j]), ps[i], ps[j]))
    
    def getVertix(self):
        return self.vertix
    
    def getEdge(self):
        return self.edge
    
    def getVertixNum(self):
        return len(self.vertix)
    
    def getEdgeNum(self):
        return len(self.edge)
    
    # Manually defined edges sorting to solve the same distance sorting problem         
    def sortEdge(self):
        if len(self.edge) > 1:
            for i in range(len(self.edge)-1):
                for j in range(i+1, len(self.edge)):
                    if self.edge[i][0] > self.edge[j][0]:
                        self.edge[i], self.edge[j] = self.edge[j], self.edge[i]

# %%
# Data structure Partition
# in the tree-based implementation, each point is regarded as a tree
# with their parent linked.
class Partition:
    def __init__(self, ps):
        self.parent = dict()
        self.rank = dict()
        self.graph = Graph(ps)   # store point sets into graph structure
        self.spanEdge = list()   # store the spanning edges
        self.pointSets = list()  # make a set of sets
        self.ps = ps
        
        for p in self.ps:   # initialize the set of sets
            s = set()
            s.add(p)
            self.pointSets.append(s)
       
    
    def getGraph(self):
        return self.graph
    
    def getParent(self):
        return self.parent
    
    def getRank(self):
        return self.rank
    
    def getSpanEdge(self):
        return self.spanEdge
        
    def getPointSets(self):
        return self.pointSets
    
    def makeSet(self, x):
        if x in self.graph.getVertix():
            self.parent[x] = x
            self.rank[x] = 0
            return True
        else:
            return False
        
    ####### Question 2, Non-path compression find method ##########
    def find(self, x):    # find root of x
        if x in self.graph.getVertix():
            while x != self.parent[x]:
                x = self.parent[x]
            return x
        else:
            return None

    ############ Answer of Question 4 ############
    # path compression in find method: make the parent of x as its root.
    def findPC(self, x): 
        if x in self.graph.getVertix():
            if x != self.parent[x]:
                self.parent[x] = self.findPC(self.parent[x])
            return x
        else:
            return None
    
    def union(self, x, y):
        A = self.find(x)
        B = self.find(y)
        if self.rank[A] > self.rank[B]:
            self.parent[B] = A
        else:
            self.parent[A] = B
            if self.rank[A] == self.rank[B]:
                self.rank[B] += 1
        # combine the sets, to make sure all the node in same tree is also in same set
        indx = -1
        indy = -1
        for i in range(len(self.pointSets)):
            if x in self.pointSets[i]:
                indx = i    # store the set list index of x
            if y in self.pointSets[i]:
                indy = i    # store the set list index of y
        pSetX = self.pointSets[indx]
        pSetY = self.pointSets.pop(indy)
        self.pointSets[self.pointSets.index(pSetX)] = self.pointSets[self.pointSets.index(pSetX)] | pSetY
                        
    def kruskal(self):
        self.graph.sortEdge()
        edges = self.graph.getEdge()
        for v in self.graph.getVertix():
            self.makeSet(v)
        for i in edges:
            weight, v1, v2 = i
            if self.find(v1) != self.find(v2):
                self.union(v1, v2)
                self.spanEdge.append(i)
        return self.spanEdge
    
    ############ Question 5, k-cluster kruskal #############
    def kClusterKruskal(self, k):  # define the k cluster kruskal
        self.graph.sortEdge()
        edges = self.graph.getEdge()
        for v in self.graph.getVertix():
            self.makeSet(v)
        for i in edges:
            if len(self.pointSets) == k:   # use the number of sets to determine k-cluster
                break
            else:
                weight, v1, v2 = i
                if self.find(v1) != self.find(v2):
                    self.union(v1, v2)
                    self.spanEdge.append(i)
        return self.spanEdge
    
    ############# Question 6 ############
    def inSameCluster(self, x, y):
        if x in self.graph.getVertix() and y in self.graph.getVertix():
            if self.findPC(x) == self.findPC(y):
                return True
            else:
                return False
        else:
            return False
    
    ############ Question 7, Denn Index ############# 
    # DennIndex = min distance between village / max distance in one village
    def dennIndex(self):
        if len(self.pointSets) == 1:
            return 0
        else:
            # minimum distance between villages
            self.graph.sortEdge()
            graphEdges = self.graph.getEdge()
            maxSpanEdges = self.spanEdge[-1]
            ind = graphEdges.index(maxSpanEdges)
            minBetVil = 0
            while True:
                ind += 1
                weight, v1, v2 = graphEdges[ind]
                if self.findPC(v1) != self.findPC(v2):
                    minBetVil = weight
                    break
            # maximum distance in villages
            maxInVil = 0
            for i in self.pointSets:
                if len(i) > 1:
                    village = Graph(list(i))
                    village.sortEdge()
                    weight, v1, v2 = village.getEdge()[-1]
                    if weight > maxInVil:
                        maxInVil = weight
                
            dunn = minBetVil/maxInVil
            return dunn

# %% [markdown]
# ## Question 3:
# Using the Partition ADT and test data function that you wrote for the first two tasks,
# implement the clustering procedure described above. If you did not manage to implement
# the tree structure or the forest structure in the earlier tasks, you may do so using the simple
# list-based union-find implementation, but this will only attract partial marks.

# %%
# Create a point set with 20 points in there
ps = pointSet(20)
for i in ps:
    print("point:", i)
print("\nGenerate", len(ps), "points in total.")
# Out:
# point: (4, 43)
# point: (27, 37)
# point: (3, 88)
# point: (4, 26)
# point: (2, 0)
# point: (37, 50)
# point: (0, 31)
# point: (45, 26)
# point: (48, 89)
# point: (76, 39)
# point: (41, 82)
# point: (51, 17)
# point: (24, 76)
# point: (37, 70)
# point: (91, 27)
# point: (51, 87)
# point: (7, 14)
# point: (4, 38)
# point: (86, 92)
# point: (14, 51)
#
# Generate 20 points in total.

# %%
sets = Partition(ps)
totalWeight = 0
edges = sets.kruskal()  # cluster into one spanning tree
for i in edges:  
    weight, v1, v2 = i
    print("The two Vertices:", v1, "and", v2, "   The Weight is:", weight)
    totalWeight += weight
print("\nTotal Weight is:", round(totalWeight, 2), "\nNumber of edges:", len(edges))
print("Number of spanning tree:", len(sets.getPointSets()))
# Out:
# The two Vertices: (48, 89) and (51, 87)    The Weight is: 3.61
# The two Vertices: (4, 43) and (4, 38)    The Weight is: 5.0
# The two Vertices: (4, 26) and (0, 31)    The Weight is: 6.4
# The two Vertices: (0, 31) and (4, 38)    The Weight is: 8.06
# The two Vertices: (48, 89) and (41, 82)    The Weight is: 9.9
# The two Vertices: (45, 26) and (51, 17)    The Weight is: 10.82
# The two Vertices: (4, 26) and (7, 14)    The Weight is: 12.37
# The two Vertices: (41, 82) and (37, 70)    The Weight is: 12.65
# The two Vertices: (4, 43) and (14, 51)    The Weight is: 12.81
# The two Vertices: (24, 76) and (37, 70)    The Weight is: 14.32
# The two Vertices: (2, 0) and (7, 14)    The Weight is: 14.87
# The two Vertices: (27, 37) and (37, 50)    The Weight is: 16.4
# The two Vertices: (27, 37) and (14, 51)    The Weight is: 19.1
# The two Vertices: (76, 39) and (91, 27)    The Weight is: 19.21
# The two Vertices: (37, 50) and (37, 70)    The Weight is: 20.0
# The two Vertices: (27, 37) and (45, 26)    The Weight is: 21.1
# The two Vertices: (3, 88) and (24, 76)    The Weight is: 24.19
# The two Vertices: (76, 39) and (51, 17)    The Weight is: 33.3
# The two Vertices: (51, 87) and (86, 92)    The Weight is: 35.36
#
# Total Weight is: 299.47
# Number of edges: 19
# Number of spanning tree: 1

# %% [markdown]
# ## Question 4:
# Extend your forest-based Partition ADT class from above with path compression.

# %% [markdown]
# ###### - Answer:
# * Already wrote in Question 2: Partition ADT
# * Method findPC(self, x)

# %% [markdown]
# ## Question 5:
# Ultimately, we are aiming to find k-clusters i.e. we want to the electricity providers to see
# the structure of the micro-grid if they decide to commission k micro-grids such that all the
# nodes are covered in the vicinity of these sub-stations. Extend your implementation such
# that it stops when k clusters have been achieved and return those clusters, where k is a
# user-definable parameter.

# %%
kClusterSets = Partition(ps)
spanEdges = kClusterSets.kClusterKruskal(6)
print("Total point sets:", [p.getPoint() for p in ps])
for i in spanEdges:
    print("Weight:", i[0], " Between:", i[1].__str__(), "and", i[2].__str__())
print("\nEdges number:", len(spanEdges), "\nNumber of villages:", len(kClusterSets.getPointSets()))
# Out:
# Total point sets: [(4, 43), (27, 37), (3, 88), (4, 26), (2, 0), (37, 50), (0, 31), (45, 26), (48, 89), (76, 39), (41, 82), (51, 17), (24, 76), (37, 70), (91, 27), (51, 87), (7, 14), (4, 38), (86, 92), (14, 51)]
# Weight: 3.61  Between: (48, 89) and (51, 87)
# Weight: 5.0  Between: (4, 43) and (4, 38)
# Weight: 6.4  Between: (4, 26) and (0, 31)
# Weight: 8.06  Between: (0, 31) and (4, 38)
# Weight: 9.9  Between: (48, 89) and (41, 82)
# Weight: 10.82  Between: (45, 26) and (51, 17)
# Weight: 12.37  Between: (4, 26) and (7, 14)
# Weight: 12.65  Between: (41, 82) and (37, 70)
# Weight: 12.81  Between: (4, 43) and (14, 51)
# Weight: 14.32  Between: (24, 76) and (37, 70)
# Weight: 14.87  Between: (2, 0) and (7, 14)
# Weight: 16.4  Between: (27, 37) and (37, 50)
# Weight: 19.1  Between: (27, 37) and (14, 51)
# Weight: 19.21  Between: (76, 39) and (91, 27)
#
# Edges number: 14
# Number of villages: 6

# %%
for i in ps:
    print(i, "has root:", kClusterSets.getParent()[i])
# Out:
# (4, 43) has root: (4, 38)
# (27, 37) has root: (37, 50)
# (3, 88) has root: (3, 88)
# (4, 26) has root: (0, 31)
# (2, 0) has root: (4, 38)
# (37, 50) has root: (4, 38)
# (0, 31) has root: (4, 38)
# (45, 26) has root: (51, 17)
# (48, 89) has root: (51, 87)
# (76, 39) has root: (91, 27)
# (41, 82) has root: (51, 87)
# (51, 17) has root: (51, 17)
# (24, 76) has root: (51, 87)
# (37, 70) has root: (51, 87)
# (91, 27) has root: (91, 27)
# (51, 87) has root: (51, 87)
# (7, 14) has root: (4, 38)
# (4, 38) has root: (4, 38)
# (86, 92) has root: (86, 92)
# (14, 51) has root: (4, 38)

# %%
for i in kClusterSets.getPointSets():
    print("A village:", [j.__str__() for j in i])
# Out:
# A village: ['(14, 51)', '(7, 14)', '(2, 0)', '(4, 26)', '(0, 31)', '(27, 37)', '(37, 50)', '(4, 38)', '(4, 43)']
# A village: ['(3, 88)']
# A village: ['(45, 26)', '(51, 17)']
# A village: ['(76, 39)', '(91, 27)']
# A village: ['(24, 76)', '(37, 70)', '(51, 87)', '(41, 82)', '(48, 89)']
# A village: ['(86, 92)']

# %% [markdown]
# ## Question 6:
# Implement functions/methods to let the user query whether two given points (nodes)
# belong to the same cluster (micro-grid).

# %%
p1 = ps[3]
p2 = ps[5]
print("The points,", p1, "and", p2, "have same root:")
kClusterSets.inSameCluster(p1, p2)
# Out:
# The points, (4, 26) and (37, 50) have same root:
# False

# %% [markdown]
# ## Question 7:
# Define a function to compute the Dunn index, a measure for the quality of the clustering.

# %%
print("Denn Index is:", kClusterSets.dennIndex())
# Out:
# Denn Index is: 0.3277076847452073

# %% [markdown]
# ## Question 8:
# Compare the forest that you have generated for the k-clustering to the full minimum cost
# spanning tree. Give a brief, but precise characterization of the sets of edges that are in the
# MCST but not in the forest of the k-clustering.

# %% [markdown]
# ###### - Answer:
# The aim of k-clustering is to decide k number of villages, and each village has a micro-grad. The sets of edges which are in MCST but not in k-clustering are the lines connected between different micro-grads in villages. Using MCST is to make the villages connecting lines have lowest cost between every two villages.

# %% [markdown]
# ## Bonus:

# %%
# for This bonus, I use Bokeh in Anaconda Jupyter Notebook
# install Bokeh in Anaconda prompt: conda install bokeh
# install Bokehlab which is used in Jupyter: conda install -c conda-forge jupyterlab
from bokeh.io import push_notebook, show, output_notebook
from bokeh.models import HoverTool, BoxSelectTool #For enabling tools
from ipywidgets import interact
import numpy as np
from bokeh.plotting import figure

# %%
x = list()
y = list()
for i in ps:
    x.append(i.getPoint()[0])
    y.append(i.getPoint()[1])

# %%
# MCST graph
output_notebook()
TOOLS = [BoxSelectTool(), HoverTool()]
p = figure(title="Spanning Tree", plot_width=800, plot_height=800, tools=TOOLS)
p.circle(x, y, size=10, color="black")
t = show(p, notebook_handle=True)
for i in sets.getSpanEdge():
    v1, v2 = i[1], i[2]
    x1, y1 = v1.getPoint()
    x2, y2 = v2.getPoint()
    xx = [x1, x2]
    yy = [y1, y2]
    p.line(xx, yy, line_width=2, color="orange")
    push_notebook(handle=t)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="53a84414-a36a-42ee-b715-e251b264c6cf">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="31c1e827-50ca-4ba7-935f-e60f0509c68b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("31c1e827-50ca-4ba7-935f-e60f0509c68b");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("31c1e827-50ca-4ba7-935f-e60f0509c68b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '31c1e827-50ca-4ba7-935f-e60f0509c68b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"19758d7e-3054-4a30-af7d-21fc26044a2d":{"roots":{"references":[{"attributes":{},"id":"47cfa766-50db-46c6-9d15-a654e935fbad","type":"BasicTickFormatter"},{"attributes":{},"id":"47c63e69-db82-4580-83ce-151382f7f663","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":"Spanning Tree"},"id":"0a60a212-08fa-473b-982f-53e2596d23d6","type":"Title"},{"attributes":{"callback":null},"id":"ae87212c-5ff6-4182-8eb3-9ac39c99c919","type":"HoverTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"00acef62-4a1a-43db-823a-6f8b17697cff","type":"BoxSelectTool"},{"id":"ae87212c-5ff6-4182-8eb3-9ac39c99c919","type":"HoverTool"}]},"id":"def6d8b9-bfc1-4833-86b3-8831a36b562a","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[4,27,3,4,2,37,0,45,48,76,41,51,24,37,91,51,7,4,86,14],"y":[43,37,88,26,0,50,31,26,89,39,82,17,76,70,27,87,14,38,92,51]}},"id":"40d563b9-8d66-4940-98ea-79063161c4e2","type":"ColumnDataSource"},{"attributes":{"callback":null,"overlay":{"id":"f8a432fe-ddd7-470e-b2df-c2f16f165c94","type":"BoxAnnotation"},"renderers":[{"id":"e8b0faae-172c-4c75-b311-63d48bb6f3d4","type":"GlyphRenderer"}]},"id":"00acef62-4a1a-43db-823a-6f8b17697cff","type":"BoxSelectTool"},{"attributes":{"dimension":1,"plot":{"id":"301215b6-cf2f-4314-ab3b-24b446c74746","subtype":"Figure","type":"Plot"},"ticker":{"id":"f0a6dc1d-43bb-4c47-8ae7-6da5513951d6","type":"BasicTicker"}},"id":"23bf1177-b557-4a30-8162-cb77c0c13c87","type":"Grid"},{"attributes":{"source":{"id":"40d563b9-8d66-4940-98ea-79063161c4e2","type":"ColumnDataSource"}},"id":"b489538d-4a2a-4868-8515-4638cb115b32","type":"CDSView"},{"attributes":{"data_source":{"id":"40d563b9-8d66-4940-98ea-79063161c4e2","type":"ColumnDataSource"},"glyph":{"id":"a5e3408a-becc-4528-827e-ab73ca68a97d","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"4fdf0480-eb10-4092-aff0-29a4a642ef0a","type":"Circle"},"selection_glyph":null,"view":{"id":"b489538d-4a2a-4868-8515-4638cb115b32","type":"CDSView"}},"id":"e8b0faae-172c-4c75-b311-63d48bb6f3d4","type":"GlyphRenderer"},{"attributes":{},"id":"f0a6dc1d-43bb-4c47-8ae7-6da5513951d6","type":"BasicTicker"},{"attributes":{"below":[{"id":"07172b5b-7b3a-45e5-9fe4-01b06fc3f5e4","type":"LinearAxis"}],"left":[{"id":"5a979569-e803-4211-8ae8-58d8788537cd","type":"LinearAxis"}],"plot_height":800,"plot_width":800,"renderers":[{"id":"07172b5b-7b3a-45e5-9fe4-01b06fc3f5e4","type":"LinearAxis"},{"id":"59daaf9d-db53-4c92-8a93-9232d3e1f12d","type":"Grid"},{"id":"5a979569-e803-4211-8ae8-58d8788537cd","type":"LinearAxis"},{"id":"23bf1177-b557-4a30-8162-cb77c0c13c87","type":"Grid"},{"id":"f8a432fe-ddd7-470e-b2df-c2f16f165c94","type":"BoxAnnotation"},{"id":"e8b0faae-172c-4c75-b311-63d48bb6f3d4","type":"GlyphRenderer"}],"title":{"id":"0a60a212-08fa-473b-982f-53e2596d23d6","type":"Title"},"toolbar":{"id":"def6d8b9-bfc1-4833-86b3-8831a36b562a","type":"Toolbar"},"x_range":{"id":"7ebca6f1-31c3-4614-ac8a-f19dd6b3b805","type":"DataRange1d"},"x_scale":{"id":"457475e9-682d-4227-82eb-1344252399cb","type":"LinearScale"},"y_range":{"id":"199a7bd8-a49a-4234-be2d-db79ea3977f4","type":"DataRange1d"},"y_scale":{"id":"8f392e12-8760-4dbc-b762-bddd6dd32802","type":"LinearScale"}},"id":"301215b6-cf2f-4314-ab3b-24b446c74746","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"7ebca6f1-31c3-4614-ac8a-f19dd6b3b805","type":"DataRange1d"},{"attributes":{"callback":null},"id":"199a7bd8-a49a-4234-be2d-db79ea3977f4","type":"DataRange1d"},{"attributes":{},"id":"8f392e12-8760-4dbc-b762-bddd6dd32802","type":"LinearScale"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"4fdf0480-eb10-4092-aff0-29a4a642ef0a","type":"Circle"},{"attributes":{},"id":"dc5e3e31-54c8-471c-93da-fab817b0746 ...

# %%
# k-cluster graph
output_notebook()
TOOLS = [BoxSelectTool(), HoverTool()]
p1 = figure(title="k-cluster", plot_width=800, plot_height=800, tools=TOOLS)
p1.circle(x, y, size=10, color="black")
t1 = show(p1, notebook_handle=True)
for ii in kClusterSets.getSpanEdge():
    v1, v2 = ii[1], ii[2]
    x1, y1 = v1.getPoint()
    x2, y2 = v2.getPoint()
    xx = [x1, x2]
    yy = [y1, y2]
    p1.line(xx, yy, line_width=2, color="red")
    push_notebook(handle=t1)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="37159dfa-6425-4acb-a8e4-50e52647b436">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="37862367-9dc5-4617-af2c-f122a384c0b6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("37862367-9dc5-4617-af2c-f122a384c0b6");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("37862367-9dc5-4617-af2c-f122a384c0b6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '37862367-9dc5-4617-af2c-f122a384c0b6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"944410fe-fcd5-4dc7-9d39-da2b859d2c92":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[4,27,3,4,2,37,0,45,48,76,41,51,24,37,91,51,7,4,86,14],"y":[43,37,88,26,0,50,31,26,89,39,82,17,76,70,27,87,14,38,92,51]}},"id":"73a541a7-ae41-40b9-a90c-06f4afa5480b","type":"ColumnDataSource"},{"attributes":{"formatter":{"id":"4c794cee-e06a-4334-ae50-053de7771ab1","type":"BasicTickFormatter"},"plot":{"id":"68f6545a-455d-4e3a-b879-3bcb65e864b7","subtype":"Figure","type":"Plot"},"ticker":{"id":"307ca56e-3269-4db6-b7b4-34f46b1c9a24","type":"BasicTicker"}},"id":"38aad7ad-68ca-4b79-845d-5ff0efa5380e","type":"LinearAxis"},{"attributes":{},"id":"609e2da1-cfba-4f14-9ea9-19eef821bce7","type":"LinearScale"},{"attributes":{"callback":null,"overlay":{"id":"c5a460cd-490b-4269-a3e1-a78392f47d2c","type":"BoxAnnotation"},"renderers":[{"id":"bc8a6cc6-7279-4239-bd54-6453ffccfeb6","type":"GlyphRenderer"}]},"id":"2824ef09-08c0-4c5e-a9d6-27b7e6aa0b57","type":"BoxSelectTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"7a1625bc-5052-433a-8c98-75fb377ddacc","type":"Circle"},{"attributes":{},"id":"d6e45a41-5c3e-4537-9c45-b066d26632a9","type":"LinearScale"},{"attributes":{},"id":"c55666a8-4b42-45bd-a55b-2678f79128b6","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c5a460cd-490b-4269-a3e1-a78392f47d2c","type":"BoxAnnotation"},{"attributes":{},"id":"c6f2e3f5-b08a-4ea7-92ee-dac84103c4b2","type":"BasicTicker"},{"attributes":{"plot":{"id":"68f6545a-455d-4e3a-b879-3bcb65e864b7","subtype":"Figure","type":"Plot"},"ticker":{"id":"307ca56e-3269-4db6-b7b4-34f46b1c9a24","type":"BasicTicker"}},"id":"d130adef-e3aa-4c05-b0c2-c3866090f8a3","type":"Grid"},{"attributes":{},"id":"4c794cee-e06a-4334-ae50-053de7771ab1","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"c55666a8-4b42-45bd-a55b-2678f79128b6","type":"BasicTickFormatter"},"plot":{"id":"68f6545a-455d-4e3a-b879-3bcb65e864b7","subtype":"Figure","type":"Plot"},"ticker":{"id":"c6f2e3f5-b08a-4ea7-92ee-dac84103c4b2","type":"BasicTicker"}},"id":"7131a132-c095-4e7d-a8f9-95add2bf4a33","type":"LinearAxis"},{"attributes":{},"id":"307ca56e-3269-4db6-b7b4-34f46b1c9a24","type":"BasicTicker"},{"attributes":{"source":{"id":"73a541a7-ae41-40b9-a90c-06f4afa5480b","type":"ColumnDataSource"}},"id":"25336995-4f08-4574-9b23-a0b5a2af8bac","type":"CDSView"},{"attributes":{"callback":null},"id":"c97c8db2-f27b-4f0d-8507-cc25ec1798de","type":"DataRange1d"},{"attributes":{"callback":null},"id":"d1ecff7d-0155-416f-a811-89edde9ca95b","type":"HoverTool"},{"attributes":{"dimension":1,"plot":{"id":"68f6545a-455d-4e3a-b879-3bcb65e864b7","subtype":"Figure","type":"Plot"},"ticker":{"id":"c6f2e3f5-b08a-4ea7-92ee-dac84103c4b2","type":"BasicTicker"}},"id":"8187810e-0d00-4789-8cf1-1c2f644fd4ef","type":"Grid"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2824ef09-08c0-4c5e-a9d6-27b7e6aa0b57","type":"BoxSelectTool"},{"id":"d1ecff7d-0155-416f-a811-89edde9ca95b","type":"HoverTool"}]},"id":"61fcddb2-b4bc-471b-ace8-94b0d14508ce","type":"Toolbar"},{"attributes":{"data_source":{"id":"73a541a7-ae41-40b9-a90c-06f4afa5480b","type":"ColumnDataSource"},"glyph":{"id":"5ef7b69a-29fb-4c2e-ab03-cfb292787848","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"7a1625bc-5052-433a-8c98-75fb377ddacc","type":"Circle"},"selection_glyph":null,"view":{"id":"25336995-4f08-4574-9b23-a0b5a2af8bac","type":"CDSView"}},"id":"bc8a6cc6-7279-4 ...
